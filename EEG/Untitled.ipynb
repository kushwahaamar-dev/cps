# %%
SRATE = 1000
CHANNELS_OF_INTEREST = ['C3', 'C4']  
MIN_TRIALS = 10 
MIN_SIGNAL_LEN = 5000 
MIN_SCALES = 5 
ARTIFACT_THRESHOLD = 100 
FEEDBACK_START = int(2000 / 1000 * SRATE) 
FEEDBACK_END = int(4000 / 1000 * SRATE)
